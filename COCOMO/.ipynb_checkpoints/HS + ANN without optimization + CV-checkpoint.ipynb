# %%
import numpy as np
from sklearn.svm import SVR
from sklearn.model_selection import train_test_split , KFold
from sklearn.metrics import mean_absolute_error
from sklearn.preprocessing import StandardScaler
import pandas as pd
import math
from bayes_opt import BayesianOptimization
import random
import sklearn
from sklearn.metrics import mean_squared_error
import tensorflow as tf
cocomo=pd.read_csv("C:\\Users\\Asus\\Desktop\\Tehran university\\Seminar\\Datasets\\cocomo81_dataset.csv",header=None)
columns_cocomo=['rely','data','cplx','time','stor','virt','turn','acap','aexp','pcap','vexp','lexp','modp','tool','sced','loc','actual']
cocomo.set_axis(columns_cocomo,axis='columns',inplace=True)
cocomo.set_axis(range(1,64),axis=0 ,inplace=True)
cocomo.rename_axis("Features", axis=1,inplace=True)
cocomo.rename_axis("Projects", axis=0,inplace=True)

# %%
# Step 1: Collect Data (Replace with your actual data)
# Load your dataset into 'X' (features) and 'y' (effort/target variable)
# Feature matrix X should have shape (n_samples, n_features)
X = cocomo.drop('actual',axis=1).values
# Target values y should have shape (n_samples,)
y = cocomo['actual'].values

seed_value = 42
random.seed(seed_value)
np.random.seed(seed_value)
tf.random.set_seed(seed_value)

# Step 2: Preprocess Data
#scaler = StandardScaler()
#X_scaled = scaler.fit_transform(X)

# Step 3: Feature Selection using Harmony Search
def objective_function(subset):
    selected_features = [feature for feature, is_selected in zip(range(X.shape[1]), subset) if is_selected]
    if len(selected_features) == 0:
        return float('-inf')  # Penalize subsets with no selected features
    
    num_folds = 5
    kf = KFold(n_splits=num_folds, shuffle=True, random_state=seed_value)
    
    X_selected = X[:, selected_features]
    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X_selected)
    error_list=[]
    
    for train_index, val_index in kf.split(X_scaled):
        X_train, X_test = X_scaled[train_index], X_scaled[val_index]
        y_train, y_test = y[train_index], y[val_index]
    
        # Step 3: Build the ANN model.
        model = tf.keras.models.Sequential([
        tf.keras.layers.Dense(units=32, activation='relu', input_shape=(X_train.shape[1],)),
        tf.keras.layers.Dense(units=16, activation='relu'),
        tf.keras.layers.Dense(units=1)  # Output layer with a single unit for regression.
    ])

        # Step 4: Compile the model.
        model.compile(optimizer='adam', loss='mean_squared_error')

        # Step 5: Train the model.
        model.fit(X_train, y_train, epochs=5, batch_size=8, verbose=1)

        # Step 6: Evaluate the model.
        y_pred = model.predict(X_test)
    
        error = np.mean(np.abs(y_pred - y_test))
        error_list.append(error)
    
    return 1 / (1 + np.mean(error_list))  # Fitness is the inverse of the error (higher is better)

#==================================================================================================================
# Harmony Search Parameters
num_features = X.shape[1]
hms = 20  # Harmony memory size
iterations = 100  # Number of iterations

# Initialize harmony memory
harmony_memory = np.random.randint(0, 2, size=(hms, num_features))

# Harmony Search Algorithm
for _ in range(iterations):
    rnd_choice=np.random.choice(hms)
    new_harmony = np.copy(harmony_memory[rnd_choice])
    for i in range(num_features):
        if np.random.rand() < 0.5:  # Adjust this probability based on your problem
            new_harmony[i] = 1 - new_harmony[i]
    current_obj = objective_function(harmony_memory[rnd_choice])
    new_obj = objective_function(new_harmony)
    if new_obj > current_obj:
        harmony_memory[rnd_choice] = new_harmony

# Get selected features based on final harmony memory
selected_features = harmony_memory[np.argmax([objective_function(i) for i in harmony_memory])]
print(selected_features)
# Step 4: Train SVR Model using selected features
#selected_X = X_scaled[:, np.array(selected_features) == 1]
#=============================================================================================================               
num_folds = 5
kf = KFold(n_splits=num_folds, shuffle=True, random_state=seed_value)
    
X_selected = X[:, selected_features]
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_selected)
mean_RMSE=[]
mean_MMRE=[]
mean_MAE=[]
    
for train_index, val_index in kf.split(X_scaled):
    X_train, X_test = X_scaled[train_index], X_scaled[val_index]
    y_train, y_test = y[train_index], y[val_index]
    
    # Step 3: Build the ANN model.
    model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(units=32, activation='relu', input_shape=(X_train.shape[1],)),
    tf.keras.layers.Dense(units=16, activation='relu'),
    tf.keras.layers.Dense(units=1)  # Output layer with a single unit for regression.
])

    # Step 4: Compile the model.
    model.compile(optimizer='adam', loss='mean_squared_error')

    # Step 5: Train the model.
    model.fit(X_train, y_train, epochs=5, batch_size=8, verbose=1)

    # Step 6: Evaluate the model.
    y_pred = model.predict(X_test)

    mae = mean_absolute_error(y_test, y_pred)
    
5000
# Epoch 10/10
# 7/7 [==============================] - 0s 833us/step - loss: 3607680.7500
# 1/1 [==============================] - 0s 311ms/step
# Epoch 1/10
# 7/7 [==============================] - 0s 2ms/step - loss: 4595541.0000
# Epoch 2/10
# 7/7 [==============================] - 0s 1ms/step - loss: 4595369.5000
# Epoch 3/10
# 7/7 [==============================] - 0s 1000us/step - loss: 4595199.5000
# Epoch 4/10
# 7/7 [==============================] - 0s 1000us/step - loss: 4595026.5000
# Epoch 5/10
# 7/7 [==============================] - 0s 1ms/step - loss: 4594843.0000
# Epoch 6/10
# 7/7 [==============================] - 0s 1ms/step - loss: 4594694.5000
# Epoch 7/10
# 7/7 [==============================] - 0s 1ms/step - loss: 4594489.5000
# Epoch 8/10
# 7/7 [==============================] - 0s 1ms/step - loss: 4594263.5000
# Epoch 9/10
# 7/7 [==============================] - 0s 1ms/step - loss: 4594098.0000
# Epoch 10/10
# 7/7 [==============================] - 0s 833us/step - loss: 4593760.5000
# 1/1 [==============================] - 0s 34ms/step
# Epoch 1/10
# 7/7 [==============================] - 0s 1ms/step - loss: 1276292.1250
# Epoch 2/10
# 7/7 [==============================] - 0s 833us/step - loss: 1276105.0000
# Epoch 3/10
# 7/7 [==============================] - 0s 833us/step - loss: 1275877.7500
# Epoch 4/10
# 7/7 [==============================] - 0s 833us/step - loss: 1275635.0000
# Epoch 5/10
# 7/7 [==============================] - 0s 833us/step - loss: 1275374.5000
# Epoch 6/10
# 7/7 [==============================] - 0s 833us/step - loss: 1275182.7500
# Epoch 7/10
# 7/7 [==============================] - 0s 833us/step - loss: 1274862.6250
# Epoch 8/10
# 7/7 [==============================] - 0s 834us/step - loss: 1274517.3750
# Epoch 9/10
# 7/7 [==============================] - 0s 833us/step - loss: 1274267.5000
# Epoch 10/10
# 7/7 [==============================] - 0s 919us/step - loss: 1273816.1250
# 1/1 [==============================] - 0s 43ms/step
# Epoch 1/10
# 7/7 [==============================] - 0s 1000us/step - loss: 4654551.5000
# Epoch 2/10
# 7/7 [==============================] - 0s 919us/step - loss: 4654213.5000
# Epoch 3/10
# 7/7 [==============================] - 0s 1000us/step - loss: 4653882.5000
# Epoch 4/10
# 7/7 [==============================] - 0s 1ms/step - loss: 4653563.0000
# Epoch 5/10
# 7/7 [==============================] - 0s 1ms/step - loss: 4653235.0000
# Epoch 6/10
# 7/7 [==============================] - 0s 833us/step - loss: 4652916.5000
# Epoch 7/10
# 7/7 [==============================] - 0s 1ms/step - loss: 4652534.0000
# Epoch 8/10
# 7/7 [==============================] - 0s 1ms/step - loss: 4652186.0000
# Epoch 9/10
# 7/7 [==============================] - 0s 833us/step - loss: 4651588.0000
# Epoch 10/10
# 7/7 [==============================] - 0s 833us/step - loss: 4651118.5000
# 1/1 [==============================] - 0s 33ms/step
# Epoch 1/10
# 7/7 [==============================] - 0s 1ms/step - loss: 4511521.5000
# Epoch 2/10
# 7/7 [==============================] - 0s 1000us/step - loss: 4511386.0000
# Epoch 3/10
# 7/7 [==============================] - 0s 999us/step - loss: 4511223.0000
# Epoch 4/10
# 7/7 [==============================] - 0s 1ms/step - loss: 4511072.5000
# Epoch 5/10
# 7/7 [==============================] - 0s 1ms/step - loss: 4510918.5000
# Epoch 6/10
# 7/7 [==============================] - 0s 1ms/step - loss: 4510804.5000
# Epoch 7/10
# 7/7 [==============================] - 0s 1ms/step - loss: 4510616.5000
# Epoch 8/10
# 7/7 [==============================] - 0s 2ms/step - loss: 4510460.0000
# Epoch 9/10
# 7/7 [==============================] - 0s 2ms/step - loss: 4510306.0000
# Epoch 10/10
# 7/7 [==============================] - 0s 2ms/step - loss: 4510063.5000
# 1/1 [==============================] - 0s 38ms/step
# Epoch 1/10
# 7/7 [==============================] - 0s 1ms/step - loss: 3608878.0000
# Epoch 2/10
# 7/7 [==============================] - 0s 1000us/step - loss: 3608709.7500
# Epoch 3/10
# 7/7 [==============================] - 0s 1ms/step - loss: 3608605.7500
# Epoch 4/10
# 7/7 [==============================] - 0s 833us/step - loss: 3608476.5000
# Epoch 5/10
# 7/7 [==============================] - 0s 999us/step - loss: 3608345.7500
# Epoch 6/10
# 7/7 [==============================] - 0s 1000us/step - loss: 3608252.0000
# Epoch 7/10
# 7/7 [==============================] - 0s 1000us/step - loss: 3608128.2500
# Epoch 8/10
# 7/7 [==============================] - 0s 833us/step - loss: 3608024.7500
# Epoch 9/10
# 7/7 [==============================] - 0s 1ms/step - loss: 3607918.7500
# Epoch 10/10
# 7/7 [==============================] - 0s 1ms/step - loss: 3607778.0000
# 1/1 [==============================] - 0s 38ms/step
# Epoch 1/10
# 7/7 [==============================] - 0s 1ms/step - loss: 4594687.5000
# Epoch 2/10
# 7/7 [==============================] - 0s 999us/step - loss: 4594466.0000
# Epoch 3/10
# 7/7 [==============================] - 0s 890us/step - loss: 4594249.5000
# Epoch 4/10
# 7/7 [==============================] - 0s 999us/step - loss: 4594017.5000
# Epoch 5/10
# 7/7 [==============================] - 0s 1ms/step - loss: 4593734.5000
# Epoch 6/10
# 7/7 [==============================] - 0s 1000us/step - loss: 4593533.5000
# Epoch 7/10
# 7/7 [==============================] - 0s 1ms/step - loss: 4593221.0000
# Epoch 8/10
# 7/7 [==============================] - 0s 833us/step - loss: 4592839.5000
# Epoch 9/10
# 7/7 [==============================] - 0s 999us/step - loss: 4592580.0000
# Epoch 10/10
# 7/7 [==============================] - 0s 833us/step - loss: 4592029.0000
# 1/1 [==============================] - 0s 36ms/step
# Epoch 1/10
# 7/7 [==============================] - 0s 1000us/step - loss: 1276968.2500
# Epoch 2/10
# 7/7 [==============================] - 0s 1ms/step - loss: 1276770.0000
# Epoch 3/10
# 7/7 [==============================] - 0s 1000us/step - loss: 1276537.5000
# Epoch 4/10
# 7/7 [==============================] - 0s 1ms/step - loss: 1276278.2500
# Epoch 5/10
# 7/7 [==============================] - 0s 1ms/step - loss: 1276011.8750
# Epoch 6/10
# 7/7 [==============================] - 0s 1ms/step - loss: 1275797.5000
# Epoch 7/10
# 7/7 [==============================] - 0s 1ms/step - loss: 1275483.0000
# Epoch 8/10
# 7/7 [==============================] - 0s 1ms/step - loss: 1275180.1250
# Epoch 9/10
# 7/7 [==============================] - 0s 1000us/step - loss: 1274959.2500
# Epoch 10/10
# 7/7 [==============================] - 0s 915us/step - loss: 1274575.0000
# 1/1 [==============================] - 0s 37ms/step
# Epoch 1/10
# 7/7 [==============================] - 0s 1ms/step - loss: 4656423.5000
# Epoch 2/10
# 7/7 [==============================] - 0s 1ms/step - loss: 4656057.5000
# Epoch 3/10
# 7/7 [==============================] - 0s 1ms/step - loss: 4655737.0000
# Epoch 4/10
# 7/7 [==============================] - 0s 1ms/step - loss: 4655461.5000
# Epoch 5/10
# 7/7 [==============================] - 0s 1ms/step - loss: 4655160.5000
# Epoch 6/10
# 7/7 [==============================] - 0s 1000us/step - loss: 4654899.5000
# Epoch 7/10
# 7/7 [==============================] - 0s 1ms/step - loss: 4654585.5000
# Epoch 8/10
# 7/7 [==============================] - 0s 1ms/step - loss: 4654307.0000
# Epoch 9/10
# 7/7 [==============================] - 0s 1ms/step - loss: 4653896.5000
# Epoch 10/10
# 7/7 [==============================] - 0s 1000us/step - loss: 4653574.0000
# 1/1 [==============================] - 0s 37ms/step
# Epoch 1/10
# 7/7 [==============================] - 0s 1ms/step - loss: 4512025.5000
# Epoch 2/10
# 7/7 [==============================] - 0s 1000us/step - loss: 4511776.5000
# Epoch 3/10
# 7/7 [==============================] - 0s 1ms/step - loss: 4511494.0000
# Epoch 4/10
# 7/7 [==============================] - 0s 1ms/step - loss: 4511204.0000
# Epoch 5/10
# 7/7 [==============================] - 0s 1ms/step - loss: 4510943.5000
# Epoch 6/10
# 7/7 [==============================] - 0s 999us/step - loss: 4510732.5000
# Epoch 7/10
# 7/7 [==============================] - 0s 1000us/step - loss: 4510404.5000
# Epoch 8/10
# 7/7 [==============================] - 0s 833us/step - loss: 4510148.5000
# Epoch 9/10
# 7/7 [==============================] - 0s 1000us/step - loss: 4509894.0000
# Epoch 10/10
# 7/7 [==============================] - 0s 1ms/step - loss: 4509513.5000
# 1/1 [==============================] - 0s 38ms/step
# Epoch 1/10
# 7/7 [==============================] - 0s 1000us/step - loss: 3608433.0000
# Epoch 2/10
# 7/7 [==============================] - 0s 1ms/step - loss: 3608211.2500
# Epoch 3/10
# 7/7 [==============================] - 0s 1000us/step - loss: 3608082.2500
# Epoch 4/10
# 7/7 [==============================] - 0s 833us/step - loss: 3607922.0000
# Epoch 5/10
# 7/7 [==============================] - 0s 1ms/step - loss: 3607721.5000
# Epoch 6/10
# 7/7 [==============================] - 0s 1ms/step - loss: 3607559.5000
# Epoch 7/10
# 7/7 [==============================] - 0s 902us/step - loss: 3607333.2500
# Epoch 8/10
# 7/7 [==============================] - 0s 1000us/step - loss: 3607121.5000
# Epoch 9/10
# 7/7 [==============================] - 0s 833us/step - loss: 3606892.2500
# Epoch 10/10
# 7/7 [==============================] - 0s 833us/step - loss: 3606581.0000
# 1/1 [==============================] - 0s 35ms/step
# Epoch 1/10
# 7/7 [==============================] - 0s 1ms/step - loss: 4595138.0000
# Epoch 2/10
# 7/7 [==============================] - 0s 1ms/step - loss: 4594966.0000
# Epoch 3/10
# 7/7 [==============================] - 0s 1ms/step - loss: 4594789.5000
# Epoch 4/10
# 7/7 [==============================] - 0s 1000us/step - loss: 4594600.5000
# Epoch 5/10
# 7/7 [==============================] - 0s 1ms/step - loss: 4594384.5000
# Epoch 6/10
# 7/7 [==============================] - 0s 999us/step - loss: 4594214.5000
# Epoch 7/10
# 7/7 [==============================] - 0s 1ms/step - loss: 4593983.5000
# Epoch 8/10
# 7/7 [==============================] - 0s 1ms/step - loss: 4593728.5000
# Epoch 9/10
# 7/7 [==============================] - 0s 1000us/step - loss: 4593547.0000
# Epoch 10/10
# 7/7 [==============================] - 0s 1ms/step - loss: 4593238.0000
# 1/1 [==============================] - 0s 38ms/step
# Epoch 1/10
# 7/7 [==============================] - 0s 1ms/step - loss: 1277153.6250
# Epoch 2/10
# 7/7 [==============================] - 0s 1ms/step - loss: 1277027.0000
# Epoch 3/10
# 7/7 [==============================] - 0s 833us/step - loss: 1276895.8750
# Epoch 4/10
# 7/7 [==============================] - 0s 833us/step - loss: 1276745.3750
# Epoch 5/10
# 7/7 [==============================] - 0s 1000us/step - loss: 1276591.2500
# Epoch 6/10
# 7/7 [==============================] - 0s 1ms/step - loss: 1276446.3750
# Epoch 7/10
# 7/7 [==============================] - 0s 1000us/step - loss: 1276266.8750
# Epoch 8/10
# 7/7 [==============================] - 0s 1000us/step - loss: 1276073.5000
# Epoch 9/10
# 7/7 [==============================] - 0s 1ms/step - loss: 1275903.5000
# Epoch 10/10
# 7/7 [==============================] - 0s 834us/step - loss: 1275649.0000
# 1/1 [==============================] - 0s 35ms/step
# Epoch 1/10
# 7/7 [==============================] - 0s 2ms/step - loss: 4655622.0000
# Epoch 2/10
# 7/7 [==============================] - 0s 2ms/step - loss: 4655384.0000
# Epoch 3/10
# ...
#     375
#     376   if not options.user_requested and conversion.is_allowlisted(f):
# --> 377     return _call_unconverted(f, args, kwargs, options)
#     378
#     379   # internal_convert_user_code is for example turned off when issuing a dynamic
#
# ~\anaconda3\lib\site-packages\tensorflow\python\autograph\impl\api.py in _call_unconverted(f, args, kwargs, options, update_cache)
#     457
#     458   if kwargs is not None:
# --> 459     return f(*args, **kwargs)
#     460   return f(*args)
#     461
#
# ~\anaconda3\lib\site-packages\tensorflow\python\distribute\distribute_lib.py in merge_fn(_, *merged_args, **merged_kwargs)
#    2869
#    2870     def merge_fn(_, *merged_args, **merged_kwargs):
# -> 2871       return self.update(var, fn, merged_args, merged_kwargs, group=group)
#    2872
#    2873     return replica_context.merge_call(merge_fn, args=args, kwargs=kwargs)
#
# ~\anaconda3\lib\site-packages\tensorflow\python\distribute\distribute_lib.py in update(self, var, fn, args, kwargs, group)
#    2990           fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
#    2991       with self._container_strategy().scope():
# -> 2992         return self._update(var, fn, args, kwargs, group)
#    2993     else:
#    2994       return self._replica_ctx_update(
#
# ~\anaconda3\lib\site-packages\tensorflow\python\distribute\distribute_lib.py in _update(self, var, fn, args, kwargs, group)
#    4060     # The implementations of _update() and _update_non_slot() are identical
#    4061     # except _update() passes `var` as the first argument to `fn()`.
# -> 4062     return self._update_non_slot(var, fn, (var,) + tuple(args), kwargs, group)
#    4063
#    4064   def _update_non_slot(self, colocate_with, fn, args, kwargs, should_group):
#
# ~\anaconda3\lib\site-packages\tensorflow\python\distribute\distribute_lib.py in _update_non_slot(self, colocate_with, fn, args, kwargs, should_group)
#    4066     # once that value is used for something.
#    4067     with UpdateContext(colocate_with):
# -> 4068       result = fn(*args, **kwargs)
#    4069       if should_group:
#    4070         return result
#
# ~\anaconda3\lib\site-packages\tensorflow\python\autograph\impl\api.py in wrapper(*args, **kwargs)
#     688       try:
#     689         with conversion_ctx:
# --> 690           return converted_call(f, args, kwargs, options=options)
#     691       except Exception as e:  # pylint:disable=broad-except
#     692         if hasattr(e, 'ag_error_metadata'):
#
# ~\anaconda3\lib\site-packages\tensorflow\python\autograph\impl\api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     375
#     376   if not options.user_requested and conversion.is_allowlisted(f):
# --> 377     return _call_unconverted(f, args, kwargs, options)
#     378
#     379   # internal_convert_user_code is for example turned off when issuing a dynamic
#
# ~\anaconda3\lib\site-packages\tensorflow\python\autograph\impl\api.py in _call_unconverted(f, args, kwargs, options, update_cache)
#     457
#     458   if kwargs is not None:
# --> 459     return f(*args, **kwargs)
#     460   return f(*args)
#     461
#
# ~\anaconda3\lib\site-packages\keras\src\optimizers\optimizer.py in apply_grad_to_update_var(var, grad)
#    1347                 return self._update_step_xla(grad, var, id(self._var_key(var)))
#    1348             else:
# -> 1349                 return self._update_step(grad, var)
#    1350
#    1351         for grad, var in grads_and_vars:
#
# ~\anaconda3\lib\site-packages\keras\src\optimizers\optimizer.py in _update_step(self, gradient, variable)
#     239                 f"`tf.keras.optimizers.legacy.{self.__class__.__name__}."
#     240             )
# --> 241         self.update_step(gradient, variable)
#     242
#     243     def compute_gradients(self, loss, var_list, tape=None):
#
# ~\anaconda3\lib\site-packages\keras\src\optimizers\adam.py in update_step(self, gradient, variable)
#     196         else:
#     197             # Dense gradients.
# --> 198             m.assign_add((gradient - m) * (1 - self.beta_1))
#     199             v.assign_add((tf.square(gradient) - v) * (1 - self.beta_2))
#     200             if self.amsgrad:
#
# ~\anaconda3\lib\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~\anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py in binary_op_wrapper(x, y)
#    1464         #   r_binary_op_wrapper use different force_same_dtype values.
#    1465         x, y = maybe_promote_tensors(x, y)
# -> 1466         return func(x, y, name=name)
#    1467       except (TypeError, ValueError) as e:
#    1468         # Even if dispatching the op failed, the RHS may be a tensor aware
#
# ~\anaconda3\lib\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~\anaconda3\lib\site-packages\tensorflow\python\util\dispatch.py in op_dispatch_handler(*args, **kwargs)
#    1174       # Fallback dispatch system (dispatch v1):
#    1175       try:
# -> 1176         return dispatch_target(*args, **kwargs)
#    1177       except (TypeError, ValueError):
#    1178         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# ~\anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py in subtract(x, y, name)
#     547 @dispatch.add_dispatch_support
#     548 def subtract(x, y, name=None):
# --> 549   return gen_math_ops.sub(x, y, name)
#     550
#     551
#
# ~\anaconda3\lib\site-packages\tensorflow\python\ops\gen_math_ops.py in sub(x, y, name)
#   12935       pass  # Add nodes to the TensorFlow graph.
#   12936   # Add nodes to the TensorFlow graph.
# > 12937   _, _, _op, _outputs = _op_def_library._apply_op_helper(
#   12938         "Sub", x=x, y=y, name=name)
#   12939   _result = _outputs[:]
#
# ~\anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py in _apply_op_helper(op_type_name, name, **keywords)
#     775   with g.as_default(), ops.name_scope(name) as scope:
#     776     if fallback:
# --> 777       _ExtractInputsAndAttrs(op_type_name, op_def, allowed_list_attr_map,
#     778                              keywords, default_type_attr_map, attrs, inputs,
#     779                              input_types)
#
# ~\anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py in _ExtractInputsAndAttrs(op_type_name, op_def, allowed_list_attr_map, keywords, default_type_attr_map, attrs, inputs, input_types)
#     548                 preferred_dtype=default_dtype)
#     549         else:
# --> 550           values = ops.convert_to_tensor(
#     551               values,
#     552               name=input_arg.name,
#
# ~\anaconda3\lib\site-packages\tensorflow\python\profiler\trace.py in wrapped(*args, **kwargs)
#     181         with Trace(trace_name, **trace_kwargs):
#     182           return func(*args, **kwargs)
# --> 183       return func(*args, **kwargs)
#     184
#     185     return wrapped
#
# ~\anaconda3\lib\site-packages\tensorflow\python\framework\ops.py in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#    1441   # TODO(b/142518781): Fix all call-sites and remove redundant arg
#    1442   preferred_dtype = preferred_dtype or dtype_hint
# -> 1443   return tensor_conversion_registry.convert(
#    1444       value, dtype, name, as_ref, preferred_dtype, accepted_result_types
#    1445   )
#
# ~\anaconda3\lib\site-packages\tensorflow\python\framework\tensor_conversion_registry.py in convert(value, dtype, name, as_ref, preferred_dtype, accepted_result_types)
#     232
#     233     if ret is None:
# --> 234       ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#     235
#     236     if ret is NotImplemented:
#
# ~\anaconda3\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py in _dense_var_to_tensor(var, dtype, name, as_ref)
#    2314
#    2315 def _dense_var_to_tensor(var, dtype=None, name=None, as_ref=False):
# -> 2316   return var._dense_var_to_tensor(dtype=dtype, name=name, as_ref=as_ref)  # pylint: disable=protected-access
#    2317
#    2318
#
# ~\anaconda3\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py in _dense_var_to_tensor(***failed resolving arguments***)
#    1556       return self.read_value().op.inputs[0]
#    1557     else:
# -> 1558       return self.value()
#    1559
#    1560   def __iadd__(self, unused_other):
#
# ~\anaconda3\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py in value(self)
#     631       return self._cached_value
#     632     with ops.colocate_with(None, ignore_existing=True):
# --> 633       return self._read_variable_op()
#     634
#     635   def _as_graph_element(self):
#
# ~\anaconda3\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py in _read_variable_op(self, no_copy)
#     792           result = read_and_set_handle(no_copy)
#     793     else:
# --> 794       result = read_and_set_handle(no_copy)
#     795
#     796     if not context.executing_eagerly():
#
# ~\anaconda3\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py in read_and_set_handle(no_copy)
#     782       if no_copy and forward_compat.forward_compatible(2022, 5, 3):
#     783         gen_resource_variable_ops.disable_copy_on_read(self.handle)
# --> 784       result = gen_resource_variable_ops.read_variable_op(
#     785           self.handle, self._dtype)
#     786       _maybe_set_handle_data(self._dtype, self.handle, result)
#
# ~\anaconda3\lib\site-packages\tensorflow\python\ops\gen_resource_variable_ops.py in read_variable_op(resource, dtype, name)
#     593   # Add nodes to the TensorFlow graph.
#     594   dtype = _execute.make_type(dtype, "dtype")
# --> 595   _, _, _op, _outputs = _op_def_library._apply_op_helper(
#     596         "ReadVariableOp", resource=resource, dtype=dtype, name=name)
#     597   _result = _outputs[:]
#
# ~\anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py in _apply_op_helper(op_type_name, name, **keywords)
#     775   with g.as_default(), ops.name_scope(name) as scope:
#     776     if fallback:
# --> 777       _ExtractInputsAndAttrs(op_type_name, op_def, allowed_list_attr_map,
#     778                              keywords, default_type_attr_map, attrs, inputs,
#     779                              input_types)
#
# ~\anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py in _ExtractInputsAndAttrs(op_type_name, op_def, allowed_list_attr_map, keywords, default_type_attr_map, attrs, inputs, input_types)
#     548                 preferred_dtype=default_dtype)
#     549         else:
# --> 550           values = ops.convert_to_tensor(
#     551               values,
#     552               name=input_arg.name,
#
# ~\anaconda3\lib\site-packages\tensorflow\python\profiler\trace.py in wrapped(*args, **kwargs)
#     181         with Trace(trace_name, **trace_kwargs):
#     182           return func(*args, **kwargs)
# --> 183       return func(*args, **kwargs)
#     184
#     185     return wrapped
#
# ~\anaconda3\lib\site-packages\tensorflow\python\framework\ops.py in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#    1441   # TODO(b/142518781): Fix all call-sites and remove redundant arg
#    1442   preferred_dtype = preferred_dtype or dtype_hint
# -> 1443   return tensor_conversion_registry.convert(
#    1444       value, dtype, name, as_ref, preferred_dtype, accepted_result_types
#    1445   )
#
# ~\anaconda3\lib\site-packages\tensorflow\python\framework\tensor_conversion_registry.py in convert(value, dtype, name, as_ref, preferred_dtype, accepted_result_types)
#     207   overload = getattr(value, "__tf_tensor__", None)
#     208   if overload is not None:
# --> 209     return overload(dtype, name)  #  pylint: disable=not-callable
#     210
#     211   for base_type, conversion_func in get(type(value)):
#
# ~\anaconda3\lib\site-packages\tensorflow\python\framework\ops.py in __tf_tensor__(self, dtype, name)
#    1335                 "building a function.",
#    1336                 name=name))
# -> 1337       return graph.capture(self, name=name)
#    1338     return super().__tf_tensor__(dtype, name)
#    1339
#
# ~\anaconda3\lib\site-packages\tensorflow\python\framework\func_graph.py in capture(self, tensor, name, shape)
#     673
#     674   def capture(self, tensor, name=None, shape=None):
# --> 675     return self._function_captures.capture_by_value(self, tensor, name)
#     676
#     677   def _validate_in_scope(self, tensor):
#
# ~\anaconda3\lib\site-packages\tensorflow\core\function\capture\capture_container.py in capture_by_value(self, graph, tensor, name)
#     135
#     136       # Large EagerTensors and resources are captured with Placeholder ops
# --> 137       return self._create_placeholder_helper(graph, tensor, name)
#     138
#     139     if tensor.graph is not graph:
#
# ~\anaconda3\lib\site-packages\tensorflow\core\function\capture\capture_container.py in _create_placeholder_helper(self, graph, tensor, name)
#     277           with_none_control_dependencies=True,
#     278           composite_device_name=composite_device_name)
# --> 279       placeholder = spec.placeholder_value(placeholder_ctx)
#     280       self.add_or_replace(
#     281           key=id(tensor),
#
# ~\anaconda3\lib\site-packages\tensorflow\python\framework\tensor.py in placeholder_value(self, placeholder_context)
#     267       # capturing placeholders outside of any control flow context.
#     268       with context_graph.control_dependencies(None):
# --> 269         placeholder = self._graph_placeholder(context_graph, name=name)
#     270     else:
#     271       placeholder = self._graph_placeholder(context_graph, name=name)
#
# ~\anaconda3\lib\site-packages\tensorflow\python\framework\tensor.py in _graph_placeholder(self, graph, name)
#     307     attrs = {"dtype": dtype_value, "shape": shape}
#     308     try:
# --> 309       op = graph._create_op_internal(  # pylint: disable=protected-access
#     310           "Placeholder", [], [dtype], input_types=[],
#     311           attrs=attrs, name=name)
#
# ~\anaconda3\lib\site-packages\tensorflow\python\framework\func_graph.py in _create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#     668       inp = self.capture(inp)
#     669       captured_inputs.append(inp)
# --> 670     return super()._create_op_internal(  # pylint: disable=protected-access
#     671         op_type, captured_inputs, dtypes, input_types, name, attrs, op_def,
#     672         compute_device)
#
# ~\anaconda3\lib\site-packages\tensorflow\python\framework\ops.py in _create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#    3379     # Session.run call cannot occur between creating and mutating the op.
#    3380     with self._mutation_lock():
# -> 3381       ret = Operation.from_node_def(
#    3382           node_def,
#    3383           self,
#
# ~\anaconda3\lib\site-packages\tensorflow\python\framework\ops.py in from_node_def(***failed resolving arguments***)
#    1887
#    1888     # Initialize c_op from node_def and other inputs
# -> 1889     c_op = _create_c_op(g, node_def, inputs, control_input_ops, op_def=op_def)
#    1890     self = Operation(c_op, GraphTensor)
#    1891     self._init(g)
#
# ~\anaconda3\lib\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~\anaconda3\lib\site-packages\tensorflow\python\framework\ops.py in _create_c_op(graph, node_def, inputs, control_inputs, op_def, extract_traceback)
#    1746
#    1747   try:
# -> 1748     c_op = pywrap_tf_session.TF_FinishOperation(op_desc)
#    1749   except errors.InvalidArgumentError as e:
#    1750     # Convert to ValueError for backwards compatibility.
#
# KeyboardInterrupt:
